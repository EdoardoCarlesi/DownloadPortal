# %%
import pandas as pd
import pickle as pkl

# %%
video_codes = 'xxyears/static/videocodes_sell.pkl'
codes = pkl.load(open(video_codes, 'rb'))
codes
# Out:
# ['pasadena-rapsody-christmas-967',
#  'della-live-sober-7692',
#  'prayer-fairy-twilight-1104',
#  'grafia-outrue-degli-8670',
#  'ending-poser-memories-7296',
#  'dello-inox-porto-7388',
#  'true-magic-nanowarriors-6463',
#  'capitan-metallalala-fires-4543',
#  'steel-maestro-entra-4130',
#  'knight-fernanduzzo-erotico-8065',
#  'gladi-stadio-mira-6113',
#  'winterstorm-fart-metal-8990',
#  'other-minore-della-9902',
#  'sober-words-sulle-7154',
#  'kitograd-poser-muscle-7328',
#  'kitograd-fart-panceri-1274',
#  'fart-fluch-knight-4799',
#  'love-schwanzwald-march-7399',
#  'dragon-noticed-chupacabra-7146',
#  'beginning-minore-scugnizzi-3513',
#  'song-forest-fernanduzzo-6675',
#  'ecologico-maestro-think-492',
#  'love-queens-ecologico-2856',
#  'outrue-formia-band-4993',
#  'fires-battalion-disco-4539',
#  'capitan-only-words-1719',
#  'valhalla-dick-tricycles-4595',
#  'will-sabbia-fart-6193',
#  'battalion-triumphant-quest-8368',
#  'nabos-legacy-gatto-4918',
# ...

# %%
new_codes1 = ['code_test1', 'code_test2', 'code_test3', 'code_test3', 'dummy_code4', 'poto_code', 'abdul_code', 'uinona_code', 'baffo_code', 'cascone_code', 'lupo_code', 'bobo_code']

# %%
for cd in new_codes1:
    codes.append(cd)

codes = list(set(codes))
    
pkl.dump(codes, open(video_codes, 'wb'))
all_codes =  []
codes = pkl.load(open(video_codes, 'rb'))
for c in codes:
    all_codes.append(c)
    if c in new_codes1:
        print(c)
# Out:
# bobo_code
# abdul_code
# code_test1
# lupo_code
# poto_code
# dummy_code4
# uinona_code
# code_test2
# baffo_code
# cascone_code
# code_test3

# %%
video_codes = 'xxyears/static/videocodes.pkl'
codes = pkl.load(open(video_codes, 'rb'))
codes
# Out:
# ['erotico-seven-gianni-6716',
#  'king-copier-midding-9249',
#  'grandfather-degli-winterstorm-5018',
#  'notte-mazurka-kaptn-8151',
#  'blood-kill-song-656',
#  'cadabra-fight-gianni-8963',
#  'story-ballad-poseur-8450',
#  'maestro-countrycycles-wall-2648',
#  'poseur-number-cadabra-5196',
#  'happy-ending-march-6030',
#  'barbie-tell-cantieri-4373',
#  'anelli-countrycycles-nanowarrior-8461',
#  'heavy-dragon-warriors-4149',
#  'radio-poseur-that-5388',
#  'reels-king-prayer-9983',
#  'twilight-onion-love-4897',
#  'emerald-libert-song-1435',
#  'triumphant-poseur-libert-9060',
#  'piazza-emerald-beginning-8317',
#  'marcia-emerald-taragnarock-3628',
#  'minerals-porto-belt-8816',
#  'houdini-night-great-7588',
#  'seven-story-birthday-5734',
#  'grande-barbie-fluch-2445',
#  'legacy-crown-valhalla-35',
#  'giorgio-warriors-only-5540',
#  'sabbia-pino-band-978',
#  'imodium-swords-muscle-4582',
#  'requiem-forest-fairy-7644',
#  'obras-carrefour-imodium-9616',
# ...

# %%
for c in codes:
    all_codes.append(c)
